# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df1 = pd.read_csv(r"C:\Users\PREETI\Downloads\DS-assignment\DS - Assignment Part 2 data set\amz_com-ecommerce_sample.csv", encoding= 'unicode_escape')
df2 = pd.read_csv(r"C:\Users\PREETI\Downloads\DS-assignment\DS - Assignment Part 2 data set\flipkart_com-ecommerce_sample.csv", encoding= 'unicode_escape')

# %%
df1.head()
# Out:
#                             uniq_id            crawl_timestamp  \
# 0  c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
# 1  7f7036a6d550aaa89d34c77bd39a5e48  2016-03-25 22:59:23 +0000
# 2  f449ec65dcbc041b6ae5e6a32717d01b  2016-03-25 22:59:23 +0000
# 3  0973b37acd0c664e3de26e97e5571454  2016-03-25 22:59:23 +0000
# 4  bc940ea42ee6bef5ac7cea3fb5cfbee7  2016-03-25 22:59:23 +0000
#
#                                          product_url  \
# 0  http://www.flipkart.com/alisha-solid-women-s-c...
# 1  http://www.flipkart.com/fabhomedecor-fabric-do...
# 2  http://www.flipkart.com/aw-bellies/p/itmeh4grg...
# 3  http://www.flipkart.com/alisha-solid-women-s-c...
# 4  http://www.flipkart.com/sicons-all-purpose-arn...
#
#                             product_name  \
# 0    Alisha Solid Women's Cycling Shorts
# 1    FabHomeDecor Fabric Double Sofa Bed
# 2                             AW Bellies
# 3    Alisha Solid Women's Cycling Shorts
# 4  Sicons All Purpose Arnica Dog Shampoo
#
# ...

# %%
df2.head()
# Out:
#                             uniq_id            crawl_timestamp  \
# 0  c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
# 1  7f7036a6d550aaa89d34c77bd39a5e48  2016-03-25 22:59:23 +0000
# 2  f449ec65dcbc041b6ae5e6a32717d01b  2016-03-25 22:59:23 +0000
# 3  0973b37acd0c664e3de26e97e5571454  2016-03-25 22:59:23 +0000
# 4  bc940ea42ee6bef5ac7cea3fb5cfbee7  2016-03-25 22:59:23 +0000
#
#                                          product_url  \
# 0  http://www.flipkart.com/alisha-solid-women-s-c...
# 1  http://www.flipkart.com/fabhomedecor-fabric-do...
# 2  http://www.flipkart.com/aw-bellies/p/itmeh4grg...
# 3  http://www.flipkart.com/alisha-solid-women-s-c...
# 4  http://www.flipkart.com/sicons-all-purpose-arn...
#
#                             product_name  \
# 0    Alisha Solid Women's Cycling Shorts
# 1    FabHomeDecor Fabric Double Sofa Bed
# 2                             AW Bellies
# 3    Alisha Solid Women's Cycling Shorts
# 4  Sicons All Purpose Arnica Dog Shampoo
#
# ...

# %% [markdown]
# #### From above two dataset we find that there is uniqu_id is common in both the dataset hence we merge these two for better observations

# %%
df = df1.merge(df2, on = 'uniq_id')

# %%
df.keys()
# Out:
# Index(['uniq_id', 'crawl_timestamp_x', 'product_url_x', 'product_name_x',
#        'product_category_tree_x', 'pid_x', 'retail_price_x',
#        'discounted_price_x', 'image_x', 'is_FK_Advantage_product_x',
#        'description_x', 'product_rating_x', 'overall_rating_x', 'brand_x',
#        'product_specifications_x', 'crawl_timestamp_y', 'product_url_y',
#        'product_name_y', 'product_category_tree_y', 'pid_y', 'retail_price_y',
#        'discounted_price_y', 'image_y', 'is_FK_Advantage_product_y',
#        'description_y', 'product_rating_y', 'overall_rating_y', 'brand_y',
#        'product_specifications_y'],
#       dtype='object')

# %%
df_final = pd.DataFrame({'Product_name':df['product_name_x'], 'Amazon_price':df['retail_price_x'], 
                         "Amazon_discounted_price": df['discounted_price_x'],
                        'Flipkart_price':df['retail_price_y'], 'Flipkart_discounted_price':df['discounted_price_y']})

# %% [markdown]
# #### Checking Null Values

# %%
df_final.isnull().sum()
# Out:
# Product_name                  0
# Amazon_price                  0
# Amazon_discounted_price       0
# Flipkart_price               78
# Flipkart_discounted_price    78
# dtype: int64

# %%
df_final.dropna(inplace = True)

# %%
df_final.to_csv("clean_data.csv")

# %%
df_final.head()
# Out:
#                             Product_name  Amazon_price  \
# 0    Alisha Solid Women's Cycling Shorts           982
# 1    FabHomeDecor Fabric Double Sofa Bed         32143
# 2                             AW Bellies           991
# 3    Alisha Solid Women's Cycling Shorts           694
# 4  Sicons All Purpose Arnica Dog Shampoo           208
#
#    Amazon_discounted_price  Flipkart_price  Flipkart_discounted_price
# 0                      438           999.0                      379.0
# 1                    29121         32157.0                    22646.0
# 2                      551           999.0                      499.0
# 3                      325           699.0                      267.0
# 4                      258           220.0                      210.0

# %%
def search():
    get = input("Enter Product Name:-")
    print("\n")
    return df_final[df_final.Product_name.str.contains(pat = str(get), case = False)]

# %%
search()
# Out:
# Enter Product Name:-Alisha Solid Women's Cycling Shorts
#                            Product_name  Amazon_price  \
# 0   Alisha Solid Women's Cycling Shorts           982
# 3   Alisha Solid Women's Cycling Shorts           694
# 6   Alisha Solid Women's Cycling Shorts          1198
# 9   Alisha Solid Women's Cycling Shorts          1197
# 13  Alisha Solid Women's Cycling Shorts           990
# 15  Alisha Solid Women's Cycling Shorts           995
#
#     Amazon_discounted_price  Flipkart_price  Flipkart_discounted_price
# 0                       438           999.0                      379.0
# 3                       325           699.0                      267.0
# 6                       602          1199.0                      479.0
# 9                       542          1199.0                      479.0
# 13                      479           999.0                      379.0
# 15                      434           999.0                      379.0
